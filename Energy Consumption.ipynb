# %% [markdown]
# ********************************Energy Consumption********************************

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"Datasets/energy_data.csv")

# %%
df.head()
# Out:
#   Building Type  Square Footage  Number of Occupants  Appliances Used  \
# 0   Residential           24563                   15                4
# 1    Commercial           27583                   56               23
# 2    Commercial           45313                    4               44
# 3   Residential           41625                   84               17
# 4   Residential           36720                   58               47
#
#    Average Temperature Day of Week  Energy Consumption
# 0                28.52     Weekday             2865.57
# 1                23.07     Weekend             4283.80
# 2                33.56     Weekday             5067.83
# 3                27.39     Weekend             4624.30
# 4                17.08     Weekday             4820.59

# %%
df.tail(5)
# Out:
#    Building Type  Square Footage  Number of Occupants  Appliances Used  \
# 95    Commercial            1161                   81               11
# 96   Residential           37943                   50               23
# 97    Commercial            1558                   27               29
# 98    Industrial            2145                   56               12
# 99   Residential           42414                   72               24
#
#     Average Temperature Day of Week  Energy Consumption
# 95                15.45     Weekend             3010.81
# 96                21.73     Weekend             4248.49
# 97                16.86     Weekend             2843.60
# 98                11.77     Weekend             3348.39
# 99                29.62     Weekday             4722.59

# %%
df.isnull().sum()
# Out:
# Building Type          0
# Square Footage         0
# Number of Occupants    0
# Appliances Used        0
# Average Temperature    0
# Day of Week            0
# Energy Consumption     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Building Type', 'Square Footage', 'Number of Occupants',
#        'Appliances Used', 'Average Temperature', 'Day of Week',
#        'Energy Consumption'],
#       dtype='object')

# %%
df['Average Temperature'].max()
# Out:
# 34.71

# %%
df['Day of Week']
# Out:
# 0     Weekday
# 1     Weekend
# 2     Weekday
# 3     Weekend
# 4     Weekday
#        ...
# 95    Weekend
# 96    Weekend
# 97    Weekend
# 98    Weekend
# 99    Weekday
# Name: Day of Week, Length: 100, dtype: object

# %%
df['Energy Consumption']
# Out:
# 0     2865.57
# 1     4283.80
# 2     5067.83
# 3     4624.30
# 4     4820.59
#        ...
# 95    3010.81
# 96    4248.49
# 97    2843.60
# 98    3348.39
# 99    4722.59
# Name: Energy Consumption, Length: 100, dtype: float64

# %%
df.info
# Out:
# <bound method DataFrame.info of    Building Type  Square Footage  Number of Occupants  Appliances Used  \
# 0    Residential           24563                   15                4
# 1     Commercial           27583                   56               23
# 2     Commercial           45313                    4               44
# 3    Residential           41625                   84               17
# 4    Residential           36720                   58               47
# ..           ...             ...                  ...              ...
# 95    Commercial            1161                   81               11
# 96   Residential           37943                   50               23
# 97    Commercial            1558                   27               29
# 98    Industrial            2145                   56               12
# 99   Residential           42414                   72               24
#
#     Average Temperature Day of Week  Energy Consumption
# ...

# %%
df['Appliances Used']
# Out:
# 0      4
# 1     23
# 2     44
# 3     17
# 4     47
#       ..
# 95    11
# 96    23
# 97    29
# 98    12
# 99    24
# Name: Appliances Used, Length: 100, dtype: int64

# %%
df.head(2)
# Out:
#   Building Type  Square Footage  Number of Occupants  Appliances Used  \
# 0   Residential           24563                   15                4
# 1    Commercial           27583                   56               23
#
#    Average Temperature Day of Week  Energy Consumption
# 0                28.52     Weekday             2865.57
# 1                23.07     Weekend             4283.80

# %%
x=df['Number of Occupants']
y=df['Energy Consumption']
plt.title('Energy Consumption on Occupants')
plt.xlabel('Occupants')
plt.ylabel('Energy Consumption')
plt.plot(x,y,'*')
plt.show()

# %%
x=df['Appliances Used']
y=df['Energy Consumption']
plt.title('Energy Consumption on Appliances')
plt.bar(x,y)
# Out:
# <BarContainer object of 100 artists>

# %%
sns.stripplot(x='Average Temperature', y='Energy Consumption', hue='Building Type' , data=df,palette="rainbow")
# Out:
# <Axes: xlabel='Average Temperature', ylabel='Energy Consumption'>

# %%
sns.countplot(x='Building Type', hue = 'Building Type', data=df)
# Out:
# <Axes: xlabel='Building Type', ylabel='count'>

# %%
sns.barplot(x='Building Type', y='Energy Consumption', data=df) #
# Out:
# <Axes: xlabel='Building Type', ylabel='Energy Consumption'>

# %% [markdown]
# most of Enegry used in inderistal area

# %%
sns.barplot(x='Day of Week', y='Energy Consumption', data=df)
# Out:
# <Axes: xlabel='Day of Week', ylabel='Energy Consumption'>

# %% [markdown]
# most of Energy used in weekday

# %%
sns.barplot( x = 'Energy Consumption',y= 'Building Type', hue='Day of Week', data=df)
# Out:
# <Axes: xlabel='Energy Consumption', ylabel='Building Type'>

# %% [markdown]
# most of the Energy Consumptin  in Commericial people in weekday

# %%
sns.countplot( x = 'Appliances Used',data = df, hue='Building Type')
sns.set_theme(rc={'figure.figsize':(10,5)})

# %% [markdown]
# most of the Appliances used in Residential area

# %%
sns.barplot( x = 'Appliances Used',y = 'Energy Consumption', data = df, hue='Building Type')
sns.set_theme(rc={'figure.figsize':(20,5)})

# %% [markdown]
# ****************Conclusion****************

# %% [markdown]
# 1. Most of the area covered by Residential but more Energy Consumption is in Induristries
# 2. In  Weekday most of Energy Consumption is in Commercial area
# 3. Most of the Appliances used in Residential area but Energy Consumption is in Induristrial and Commericial space
